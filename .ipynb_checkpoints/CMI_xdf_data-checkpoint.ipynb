# %%
from xdf_proc.MobiXDF import MobiXDF
import pandas as pd
import os

# %%
fpath = '/data2/Projects/NKI_RS2/MoBI/sub-M10937776/ses-MOBI1A/lsl/sub-M10937776_ses-MOBI1A_task-spirals_run-001_lsl.xdf.gz'
mobi = MobiXDF(fpath)
mobi.get_channel_timeseries('MindLogger').x.unique()
# Out:
# Stream 8: Calculated effective sampling rate 92.9137 Hz is different from specified rate 1000.0000 Hz.
# array(['0'], dtype=object)
